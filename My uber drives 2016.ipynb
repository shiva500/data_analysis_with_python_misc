# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Dell\Desktop\Data Warehouse\UberDrives2016.csv')

# %%
df.head()
df.tail()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# ## Place mouse cursor inside the head parenthesis.Press shift + Tab for additional information.

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
 #Find Rows and columns
df.shape
# Out:
# (1156, 7)

# %%
#df["START_DATE*"]=pd.to_datetime(df["START_DATE*"])

# %% [markdown]
# ## Dataset Summerization

# %%
df.describe(include="all")
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*        MILES*  \
# count              1156             1155      1155   1155  1155   1156.000000
# unique             1155             1154         2    177   188           NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary           NaN
# freq                  2                2      1078    201   203           NaN
# mean                NaN              NaN       NaN    NaN   NaN     21.115398
# std                 NaN              NaN       NaN    NaN   NaN    359.299007
# min                 NaN              NaN       NaN    NaN   NaN      0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN      2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN      6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN     10.400000
# max                 NaN              NaN       NaN    NaN   NaN  12204.700000
#
#        PURPOSE*
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
# START_DATE*    1156 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1156 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
# Count of unique start location
df["START*"].value_counts()
# Out:
# Cary                          201
# Unknown Location              148
# Morrisville                    85
# Whitebridge                    68
# Islamabad                      57
# Durham                         37
# Lahore                         36
# Raleigh                        28
# Kar?chi                        27
# Apex                           17
# Westpark Place                 17
# Berkeley                       16
# Midtown                        14
# Kenner                         11
# Kissimmee                      11
# R?walpindi                     11
# Emeryville                     10
# New Orleans                    10
# Downtown                        9
# Central                         8
# Colombo                         8
# San Francisco                   8
# Orlando                         8
# Banner Elk                      8
# Edgehill Farms                  8
# Oakland                         7
# The Drag                        7
# ...

# %% [markdown]
# ## Data Manipulation tasks

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.iloc[0:5,0:4] #rows and columns
df.iloc[0:5,[0,3]] # 0th and 3rd column
# Out:
#       START_DATE*       START*
# 0  1/1/2016 21:11  Fort Pierce
# 1   1/2/2016 1:25  Fort Pierce
# 2  1/2/2016 20:25  Fort Pierce
# 3  1/5/2016 17:31  Fort Pierce
# 4  1/6/2016 14:42  Fort Pierce

# %%
df.iloc[0:4] # select all the columns
df.iloc[:,0:4] # select all the rows
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.iloc[:,: -1]  # all the rows and columns except the last column
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
# Label based indexing
df.loc[:,["START*","STOP*"]]

# instead use in place of above for best practices
# Calculates only 
abc = df[["START*","STOP*"]]
type(abc)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %% [markdown]
# ## Filtering

# %%
df2 = df.loc[df["MILES*"]>10]
df2


df2 = df.loc[df["MILES*"]>10,["MILES*","START*"]]
df2
# Out:
#        MILES*               START*
# 4        63.7          Fort Pierce
# 9        16.5              Jamaica
# 10       10.8             New York
# 22       15.1             New York
# 23       11.2             Downtown
# 24       11.8              Gulfton
# 25       21.9              Houston
# 28       10.4                 Cary
# 29       10.4               Durham
# 34       17.1                 Cary
# 35       15.1  Fayetteville Street
# 36       40.2              Raleigh
# 46       18.7                 Cary
# 49       12.9              Raleigh
# 50       19.0                 Cary
# 51       14.7      Meredith Townes
# 52       15.7              Raleigh
# 55       10.4                 Cary
# 56       10.1               Durham
# 61       19.4                 Cary
# 62       23.3          Chapel Hill
# 74       10.4                 Cary
# 75       10.4               Durham
# 76       11.4                 Cary
# 91       17.3                 Cary
# 93       13.5              Raleigh
# ...

# %%
# Find out all rides from New York
df.loc[df["START*"]=="New York",["MILES*"]].head()
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %%
# Find out all rides to Cary & Morrisville
df[df["START*"].isin(["Cary","Morrisville"])].head()
my_city = df[df["START*"].isin(["Cary","Morrisville"])]
my_city.head()
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*        STOP*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business         Cary         Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business         Cary  Morrisville
# 27   1/15/2016 0:41   1/15/2016 1:01  Business  Morrisville         Cary
# 28  1/15/2016 11:43  1/15/2016 12:03  Business         Cary       Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business         Cary         Cary
#
#     MILES*         PURPOSE*
# 7      0.8          Meeting
# 8      8.3          Meeting
# 27     8.0  Errand/Supplies
# 28    10.4   Meal/Entertain
# 30     4.8   Meal/Entertain

# %%
# Find out all rides to Cary & Morrisville
df.loc[df["START*"].isin(["Cary","Morrisville"])].shape
my_rides = df.loc[df["START*"].isin(["Cary","Morrisville"])]
my_rides.head()
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*        STOP*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business         Cary         Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business         Cary  Morrisville
# 27   1/15/2016 0:41   1/15/2016 1:01  Business  Morrisville         Cary
# 28  1/15/2016 11:43  1/15/2016 12:03  Business         Cary       Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business         Cary         Cary
#
#     MILES*         PURPOSE*
# 7      0.8          Meeting
# 8      8.3          Meeting
# 27     8.0  Errand/Supplies
# 28    10.4   Meal/Entertain
# 30     4.8   Meal/Entertain

# %%
df.loc[~df["START*"].isin(["Cary","Morrisville"])].shape
my_filt = df.loc[~df["START*"].isin(["Cary","Morrisville"])]
my_filt.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df3 = df.loc[(df["MILES*"] > 10) & (df["START*"].isin(["Cary","New York"]))]
#df3.reset_index()
#change the original Data Frame df3
df3.reset_index(inplace = True,drop= True) # drop the index column
df3
# Out:
#          START_DATE*         END_DATE* CATEGORY*    START*             STOP*  \
# 0    1/10/2016 15:08   1/10/2016 15:51  Business  New York            Queens
# 1    1/12/2016 16:02   1/12/2016 17:00  Business  New York     Queens County
# 2    1/15/2016 11:43   1/15/2016 12:03  Business      Cary            Durham
# 3    1/20/2016 10:36   1/20/2016 11:11  Business      Cary           Raleigh
# 4    1/27/2016 10:19   1/27/2016 10:48  Business      Cary           Raleigh
# 5    1/28/2016 12:28   1/28/2016 13:00  Business      Cary           Raleigh
# 6    1/29/2016 11:43   1/29/2016 12:03  Business      Cary            Durham
# 7     2/1/2016 10:35    2/1/2016 11:15  Business      Cary       Chapel Hill
# 8     2/5/2016 11:47    2/5/2016 12:07  Business      Cary            Durham
# 9     2/6/2016 16:20    2/6/2016 16:53  Business      Cary           Raleigh
# 10   2/11/2016 16:28   2/11/2016 17:10  Business      Cary           Raleigh
# ...

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by=["MILES*"],ascending=False).head(5)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
#
#                  STOP*   MILES*        PURPOSE*
# 1155               NaN  12204.7             NaN
# 269       Jacksonville    310.3  Customer Visit
# 270          Kissimmee    201.0         Meeting
# 881             Mebane    195.9             NaN
# 776   Unknown Location    195.6             NaN

# %%
df.sort_values(by=["START*","MILES*"],ascending=[True,False]).head(5)
# Out:
#           START_DATE*         END_DATE* CATEGORY*  START*        STOP*  \
# 906   11/4/2016 21:04   11/4/2016 21:20  Business   Agnew         Cory
# 911   11/6/2016 10:50   11/6/2016 11:04  Business   Agnew  Renaissance
# 908    11/5/2016 8:34    11/5/2016 8:43  Business   Agnew  Renaissance
# 910   11/5/2016 19:20   11/5/2016 19:28  Business   Agnew        Agnew
# 879  10/30/2016 12:58  10/30/2016 13:18  Business  Almond  Bryson City
#
#      MILES* PURPOSE*
# 906     4.3      NaN
# 911     2.4      NaN
# 908     2.2      NaN
# 910     2.2      NaN
# 879    15.2      NaN

# %% [markdown]
# ## Conditionally adding the columns

# %%
import numpy as np
df["miles_cat"]= np.where(df["MILES*"] > 5, "Long Trip","Short Trip")
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*   miles_cat
# 0     5.1   Meal/Entertain   Long Trip
# 1     5.0              NaN  Short Trip
# 2     4.8  Errand/Supplies  Short Trip
# 3     4.7          Meeting  Short Trip
# 4    63.7   Customer Visit   Long Trip

# %%
df["my_year"] = np.array(2000)

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df["miles_cat"]=np.where(df["MILES*"]>10,"Long Trip",np.where(df["MILES*"] < 5,"Short Trip","Medium Trip"))
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*    miles_cat  my_year
# 0     5.1   Meal/Entertain  Medium Trip     2000
# 1     5.0              NaN  Medium Trip     2000
# 2     4.8  Errand/Supplies   Short Trip     2000
# 3     4.7          Meeting   Short Trip     2000
# 4    63.7   Customer Visit    Long Trip     2000

# %% [markdown]
# ## Groupby Summerize

# %%
df.groupby("START*")["MILES*"].agg("mean")
#or
df.groupby("START*")["MILES*"].mean()
# Out:
# START*
# Agnew                           2.775000
# Almond                         15.200000
# Apex                            5.341176
# Arabi                          17.000000
# Arlington                       4.900000
# Arlington Park at Amberly       1.300000
# Asheville                     143.850000
# Austin                        136.000000
# Banner Elk                     12.375000
# Bellevue                       12.900000
# Berkeley                       14.375000
# Boone                         102.000000
# Briar Meadow                    9.600000
# Bryson City                    20.820000
# Burtrose                        4.800000
# CBD                             3.850000
# Capitol One                     9.450000
# Cary                            8.911940
# Central                         1.950000
# Chalmette                       1.100000
# Chapel Hill                    20.150000
# Chessington                     3.350000
# College Avenue                  2.600000
# ...

# %%
#df = df.drop(columns=["my_year"])
df
df.groupby(["START*","STOP*"]).agg(["mean","sum"]).head(20)
# Out:
#                                                          MILES*
#                                                            mean    sum
# START*                    STOP*
# Agnew                     Agnew                        2.200000    2.2
#                           Cory                         4.300000    4.3
#                           Renaissance                  2.300000    4.6
# Almond                    Bryson City                 15.200000   15.2
# Apex                      Apex                         2.150000    4.3
#                           Cary                         5.792308   75.3
#                           Eagle Rock                   2.200000    2.2
#                           Holly Springs                9.000000    9.0
# Arabi                     Metairie                    17.000000   17.0
# Arlington                 Washington                   4.900000    4.9
# Arlington Park at Amberly Lexington Park at Amberly    1.300000    1.3
# ...

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*    miles_cat
# 1151  Unknown Location      3.9  Temporary Site   Short Trip
# 1152  Unknown Location     16.2         Meeting    Long Trip
# 1153           Gampaha      6.4  Temporary Site  Medium Trip
# 1154         Ilukwatta     48.2  Temporary Site    Long Trip
# 1155               NaN  12204.7             NaN    Long Trip

# %%
 df=df.iloc[: -1,:]

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*    miles_cat
# 1150           Kar?chi     0.7         Meeting   Short Trip
# 1151  Unknown Location     3.9  Temporary Site   Short Trip
# 1152  Unknown Location    16.2         Meeting    Long Trip
# 1153           Gampaha     6.4  Temporary Site  Medium Trip
# 1154         Ilukwatta    48.2  Temporary Site    Long Trip

# %%
df["START_DATE*"]=pd.to_datetime(df["START_DATE*"])
df.dtypes
# Out:
# E:\Anacond\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# miles_cat              object
# dtype: object

# %%
df.head()
# Out:
#           START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0 2016-01-01 21:11:00  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1 2016-01-02 01:25:00   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2 2016-01-02 20:25:00  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3 2016-01-05 17:31:00  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4 2016-01-06 14:42:00  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*    miles_cat
# 0     5.1   Meal/Entertain  Medium Trip
# 1     5.0              NaN  Medium Trip
# 2     4.8  Errand/Supplies   Short Trip
# 3     4.7          Meeting   Short Trip
# 4    63.7   Customer Visit    Long Trip

# %%
res = df.groupby("START*").agg({"MILES*":["mean"],"START_DATE*":["min","max"]})
res
# Out:
#                                 MILES*         START_DATE*
#                                   mean                 min                 max
# START*
# Agnew                         2.775000 2016-11-04 21:04:00 2016-11-06 10:50:00
# Almond                       15.200000 2016-10-30 12:58:00 2016-10-30 12:58:00
# Apex                          5.341176 2016-01-29 21:21:00 2016-12-12 14:26:00
# Arabi                        17.000000 2016-06-25 10:50:00 2016-06-25 10:50:00
# Arlington                     4.900000 2016-08-02 11:51:00 2016-08-02 11:51:00
# Arlington Park at Amberly     1.300000 2016-08-01 13:08:00 2016-08-01 13:08:00
# Asheville                   143.850000 2016-10-28 20:13:00 2016-10-30 15:22:00
# Austin                      136.000000 2016-03-17 12:52:00 2016-03-17 12:52:00
# Banner Elk                   12.375000 2016-07-15 11:32:00 2016-07-17 11:23:00
# Bellevue                     12.900000 2016-05-05 23:55:00 2016-05-05 23:55:00
# ...
