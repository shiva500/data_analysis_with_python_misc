# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline

# %%
#df = pd.read_excel(r'C:\Users\Dell\Desktop\sales_order.xlsx',index_col=0)
df = pd.read_excel(r'C:\Users\Dell\Desktop\sales_order.xlsx')

# %%
df.head()
# Out:
#   Sale Order Number Sale Order Date  \
# 0   FY76/77-0000840      2076/04/26
# 1   FY76/77-0000840      2076/04/26
# 2   FY76/77-0001126      2076/05/04
# 3   FY76/77-0001126      2076/05/04
# 4   FY76/77-0001496      2076/05/16
#
#                                    Customer Name Customer Sub Group  \
# 0  Shree krishna Hardware and suppliers ,Shivpur   SO: Keshav Panta
# 1  Shree krishna Hardware and suppliers ,Shivpur   SO: Keshav Panta
# 2  Shree krishna Hardware and suppliers ,Shivpur   SO: Keshav Panta
# 3  Shree krishna Hardware and suppliers ,Shivpur   SO: Keshav Panta
# 4  Shree krishna Hardware and suppliers ,Shivpur   SO: Keshav Panta
#
#   Salesman / Agent Name Currency Code   Invoice Number Invoice Date  \
# 0                   NaN           NPR  SCPL/02148/7677   2076/04/27
# 1                   NaN           NPR  SCPL/02149/7677   2076/04/27
# 2                   NaN           NPR  SCPL/03152/7677   2076/05/05
# ...

# %%
#del_col=['Sale Order Number','Sale Order Date','Salesman/Agent Name','Currency Code','Invoice Number','Invoice Date']
#df.drop(['Sale Order Date','Salesman/Agent Name','Currency Code','Invoice Number','Invoice Date'])
#df.dtypes

#reg_plot = df.groupby("Customer Sub Group").sum().plot(kind='line')

# %%
del df['Sale Order Global Level Term Code 1 : Discount Amount (NPR)']

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#      Sale Order Date                                  Customer Name  \
# 0         2076/04/26  Shree krishna Hardware and suppliers ,Shivpur
# 1         2076/04/26  Shree krishna Hardware and suppliers ,Shivpur
# 2         2076/05/04  Shree krishna Hardware and suppliers ,Shivpur
# 3         2076/05/04  Shree krishna Hardware and suppliers ,Shivpur
# 4         2076/05/16  Shree krishna Hardware and suppliers ,Shivpur
# 5         2076/05/16  Shree krishna Hardware and suppliers ,Shivpur
# 6         2076/06/10  Shree krishna Hardware and suppliers ,Shivpur
# 7         2076/06/10  Shree krishna Hardware and suppliers ,Shivpur
# 8         2076/04/13                S.K Hardware Centre, Tarkeshwor
# 9         2076/08/06                S.K Hardware Centre, Tarkeshwor
# 10        2076/09/06                S.K Hardware Centre, Tarkeshwor
# 11        2076/05/29         Manakamana Hardware& Suppliers, Banepa
# 12        2076/06/30         Manakamana Hardware& Suppliers, Banepa
# ...

# %%
rep_plot = df_units.groupby("Customer Sub Group").sum().plot(kind='bar')
rep_plot.set_xlabel("Customer Sub Group")
#rep_plot.set_ylabel("Units")df.groupby("Customer Sub Group ").sum().sort_values("Sale Order Total Amount (NPR)", ascending=False).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-a33b1697685f> in <module>
# ----> 1 df.groupby("CustomerSubGroup ").sum().sort_values("Sale Order Total Amount (NPR)", ascending=False).plot(kind='bar')
#
# E:\Anacond\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# E:\Anacond\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# ...
