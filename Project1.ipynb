# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Dell\Desktop\datasets-master\popularidad\temporal.csv')

# %%
df.head(10)
# Out:
#           Mes  data science  machine learning  deep learning  categorical
# 0  2004-01-01            12                18              4            1
# 1  2004-02-01            12                21              2            1
# 2  2004-03-01             9                21              2            1
# 3  2004-04-01            10                16              4            1
# 4  2004-05-01             7                14              3            1
# 5  2004-06-01             9                17              3            1
# 6  2004-07-01             9                16              3            1
# 7  2004-08-01             7                14              3            1
# 8  2004-09-01            10                17              4            1
# 9  2004-10-01             8                17              4            1

# %%
df.describe()
# Out:
#        data science  machine learning  deep learning  categorical
# count    194.000000        194.000000     194.000000   194.000000
# mean      20.953608         27.396907      24.231959     0.257732
# std       23.951006         28.091490      34.476887     0.438517
# min        4.000000          7.000000       1.000000     0.000000
# 25%        6.000000          9.000000       2.000000     0.000000
# 50%        8.000000         13.000000       3.000000     0.000000
# 75%       26.750000         31.500000      34.000000     1.000000
# max      100.000000        100.000000     100.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 5 columns):
# Mes                 194 non-null object
# data science        194 non-null int64
# machine learning    194 non-null int64
# deep learning       194 non-null int64
# categorical         194 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 7.7+ KB

# %% [markdown]
# ## Visualize whole data using display option

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

# %%
df
# Out:
#             Mes  data science  machine learning  deep learning  categorical
# 0    2004-01-01            12                18              4            1
# 1    2004-02-01            12                21              2            1
# 2    2004-03-01             9                21              2            1
# 3    2004-04-01            10                16              4            1
# 4    2004-05-01             7                14              3            1
# 5    2004-06-01             9                17              3            1
# 6    2004-07-01             9                16              3            1
# 7    2004-08-01             7                14              3            1
# 8    2004-09-01            10                17              4            1
# 9    2004-10-01             8                17              4            1
# 10   2004-11-01             8                15              2            1
# ...

# %% [markdown]
# ## Apply specific format to the data

# %%
format_dict = {'data science':'${0:,.2f}','Mes':'{:%m-%Y}','machine learning':'{:.2%}'}

# %%
df['Mes']=pd.to_datetime(df['Mes'])
df.head().style.format(format_dict)
df.head()
# Out:
#          Mes  data science  machine learning  deep learning  categorical
# 0 2004-01-01            12                18              4            1
# 1 2004-02-01            12                21              2            1
# 2 2004-03-01             9                21              2            1
# 3 2004-04-01            10                16              4            1
# 4 2004-05-01             7                14              3            1

# %%
format_dict = {'Mes':'{:%m-%Y}'}
df.head().style.format(format_dict).highlight_max(color='darkgreen').highlight_min(color='#ff0000')
# Out:
# <style  type="text/css" >
#     #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row0_col1 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row0_col3 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row0_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
#         }    #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row1_col1 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row1_col2 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row1_col3 {
#             : ;
#             background-color:  #ff0000;
#         }    #T_eaaae24c_5c45_11ea_a13e_b46bfca14ec3row1_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
# ...

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science','machine learning'],cmap='BuGn')
# Out:
# <style  type="text/css" >
#     #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row0_col2 {
#             background-color:  #51b689;
#             color:  #000000;
#         }    #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row2_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }    #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_32812a52_5c46_11ea_aa59_b46bfca14ec3row3_col1 {
#             background-color:  #48b27f;
#             color:  #000000;
# ...

# %%
df.head(10).style.format(format_dict).bar(color='blue',subset=['data science','deep learning'])
# Out:
# <style  type="text/css" >
#     #T_98ae8fdc_5c46_11ea_aabd_b46bfca14ec3row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 100.0%, transparent 100.0%);
#         }    #T_98ae8fdc_5c46_11ea_aabd_b46bfca14ec3row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 100.0%, transparent 100.0%);
#         }    #T_98ae8fdc_5c46_11ea_aabd_b46bfca14ec3row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 100.0%, transparent 100.0%);
#         }    #T_98ae8fdc_5c46_11ea_aabd_b46bfca14ec3row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_98ae8fdc_5c46_11ea_aabd_b46bfca14ec3row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 40.0%, transparent 40.0%);
# ...

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = os.getcwd() + '\Desktop\ipython-notebooks-master\data\ex1data1.txt'
path
# Out:
# 'C:\\Users\\Dell\\Desktop\\ipython-notebooks-master\\data\\ex1data1.txt'

# %%
data = pd.read_csv(path,header=None,names=['Population','Profit'])
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
data.plot(kind='scatter',x='Population',y='Profit',figsize=(12,8))

# %%
import numpy as np

def computeCost(X,y,theta):
    inner = np.power(((X * theta.T) - y),2)
    return np.sum(inner) / (2 * len(X))

# %%
data.insert(0,'Ones',1)

# %%
cols = data.shape[1]
X = data.iloc[:,0:cols-1]
y = data.iloc[:,cols-1:cols]

# %%
x = np.matrix(X.values)
y = np.matrix(y.values)
theta = np.matrix(np.array([0,0]))

# %%
X.shape,theta.shape,y.shape
# Out:
# ((97, 2), (1, 2), (97, 1))

# %%
computeCost(x,y,theta)
# Out:
# 32.072733877455676
